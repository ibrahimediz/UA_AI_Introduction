# %% [markdown]
# ```
# /workspace/UA_AI_Introduction/Data/heart_disease.csv
# yukarıdaki adresten faydalanarak pandas modülünü kullanarak dataseti okuyup dataframe olarak değişken oluşturalım
# ```

# %%
import pandas as pd

# %%
df = pd.read_csv("/workspace/UA_AI_Introduction/Data/heart_disease.csv")
df
# Out:
#      age  sex  chest pain type  resting blood pressure  \
# 0     70    1                4                     130
# 1     67    0                3                     115
# 2     57    1                2                     124
# 3     64    1                4                     128
# 4     74    0                2                     120
# ..   ...  ...              ...                     ...
# 265   52    1                3                     172
# 266   44    1                2                     120
# 267   56    0                2                     140
# 268   57    1                4                     140
# 269   67    1                4                     160
#
#      serum cholestoral in mg/dl        fasting blood sugar > 120 mg/dl   \
# 0                                 322                                 0
# 1                                 564                                 0
# 2                                 261                                 0
# ...
